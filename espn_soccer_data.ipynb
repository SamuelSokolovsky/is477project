# %%
import pandas as pd

standings = pd.read_csv("/Users/samsokolovky/Desktop/is477/base_data/standings.csv")
team_stats = pd.read_csv("/Users/samsokolovky/Desktop/is477/base_data/teamStats.csv")
leagues = pd.read_csv("/Users/samsokolovky/Desktop/is477/base_data/leagues.csv")
teams = pd.read_csv("/Users/samsokolovky/Desktop/is477/base_data/teams.csv")

# %%
unique_names = leagues["leagueName"].unique()
epl = leagues[leagues["leagueName"] == "English Premier League"]
epl
# Out:
#      seasonType  year                      seasonName  \
# 222       12654  2024  2024-25 English Premier League
# 837       13481  2025  2025-26 English Premier League
#
#                          seasonSlug  leagueId midsizeName  \
# 222  2024-25-english-premier-league       700       ENG.1
# 837  2025-26-english-premier-league       700       ENG.1
#
#                  leagueName leagueShortName
# 222  English Premier League  Premier League
# 837  English Premier League  Premier League

# %%
prem = standings[(standings["leagueId"] == 700) & (standings["year"] == 2024)]
prem
# Out:
#       seasonType  year  leagueId   last_matchDateTime  teamRank  teamId  \
# 1516       12654  2024       700  2025-05-25 15:00:00         1     364
# 1517       12654  2024       700  2025-05-25 15:00:00         2     359
# 1518       12654  2024       700  2025-05-25 15:00:00         3     382
# 1519       12654  2024       700  2025-05-25 15:00:00         4     363
# 1520       12654  2024       700  2025-05-25 15:00:00         5     361
# 1521       12654  2024       700  2025-05-25 15:00:00         6     362
# 1522       12654  2024       700  2025-05-25 15:00:00         7     393
# 1523       12654  2024       700  2025-05-25 15:00:00         8     331
# 1524       12654  2024       700  2025-05-25 15:00:00         9     349
# 1525       12654  2024       700  2025-05-25 15:00:00        10     337
# 1526       12654  2024       700  2025-05-25 15:00:00        11     370
# 1527       12654  2024       700  2025-05-25 15:00:00        12     384
# ...

# %%
team_stats_epl = team_stats[team_stats["teamId"].isin([364, 359, 382, 363, 361, 362, 393, 331, 349, 337, 370, 384, 368,
       371, 360, 380, 367, 375, 373, 376])]
team_stats_epl.head()
# Out:
#        seasonType  eventId  teamId  teamOrder  possessionPct  foulsCommitted  \
# 16562       12282   700485     360          1           45.5             4.0
# 16563       12282   700486     363          0           74.8            13.0
# 16565       12282   700487     359          0           58.0            10.0
# 16566       12282   700487     360          1           42.0            11.0
# 16567       12282   700488     364          0           39.9            14.0
#
#        yellowCards  redCards  offsides  wonCorners  ...  accurateLongBalls  \
# 16562          0.0       0.0       1.0         1.0  ...               11.0
# 16563          1.0       0.0       1.0         5.0  ...               29.0
# 16565          0.0       0.0       5.0         3.0  ...               24.0
# 16566          0.0       0.0       0.0         6.0  ...               16.0
# 16567          1.0       0.0       3.0         1.0  ...               15.0
#
# ...

# %%
prem_teams = teams[teams["teamId"].isin([364, 359, 382, 363, 361, 362, 393, 331, 349, 337, 370, 384, 368,
       371, 360, 380, 367, 375, 373, 376])]
prem_teams
# Out:
#      teamId                 location                     name abbreviation  \
# 211     331   Brighton & Hove Albion   Brighton & Hove Albion          BHA
# 217     337                Brentford                Brentford          BRE
# 229     349          AFC Bournemouth          AFC Bournemouth          BOU
# 236     359                  Arsenal                  Arsenal          ARS
# 237     360        Manchester United        Manchester United          MAN
# 238     361         Newcastle United         Newcastle United          NEW
# 239     362              Aston Villa              Aston Villa          AVL
# 240     363                  Chelsea                  Chelsea          CHE
# 241     364                Liverpool                Liverpool          LIV
# 244     367        Tottenham Hotspur        Tottenham Hotspur          TOT
# 245     368                  Everton                  Everton          EVE
# ...
